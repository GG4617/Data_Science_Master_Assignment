# %% [markdown]
# *<u>PYTHON</u>*
#
# **<u>Assignment questions</u>**
#
# > **1.Who developed python programming Language ?**
# >
# > **Ans. Guido van Rossum developed the python programming language .**
# >
# > **2. Which type of programming does a python support ?**
# >
# > **Ans. Python support object-oriented programming .**
# >
# > **3. Is python case sensitives when dealing with identifiers?**
# >
# > **Ans. Yes,python is a case sensitive language thus dealing with the
# > identifiers it can**
# >
# > **also act as a case-sensitive.**
# >
# > **4. What is the correct extension of a python file ?**
# >
# > **Ans. The correct extension of a python file is .py**
# >
# > **5. Is python code compiled or interpreted ?**
# >
# > **Ans. Python is a interpreted language from which it can be converted
# > into bytecode.**
# >
# > **6. Name a few blocks of code used to define in python language?**
# >
# > **Ans. A module ,function body and a class definition is a few blocks
# > of code which is used**
# >
# > **in python.**
# >
# > **7. State a character used to give a single-line comments in
# > python?**
# >
# > **Ans. HAsh symbol (#) is used to define a single- line comment in
# > python language.**
# >
# > **8. Mention functions which can help us to find the version of python
# > that we are**
# >
# > **currently working on?**
# >
# > **Ans. The function sys. is used to find the version of python that we
# > are currently**
# >
# > **working on.**
# >
# > **9. Python supports the creation of anonymous functions at
# > runtime,using a construct**
# >
# > **called as ?**
# >
# > **Ans. Python supports the creation of anonymous functions at runtime
# > using a construct**
# >
# > **called as lambda .**
# >
# > **10. What does a pip stand for python?**
# >
# > **Ans. Pip stand for preferred installer program in python programming
# > language.**
# >
# > **11. Mention a few built in function in python ?**
# >
# > **Ans. The built-in function of a python are as follows :**
# >
# > **bool(),dict(),chr(),float(),int() etc..**
# >
# > **12. What is the maximum possible length of an identifier in
# > python?**
# >
# > **Ans. 79 character is the maximum length of an identifier in
# > python.**
# >
# > **13. What are the benefits of using python?**
# >
# > **Ans. Easy to Read Learn and Write , Improved Productivity , portable
# > , secure , free and open**
# >
# > **source , interpreted language.These are the benefits of using a
# > python.**
# >
# > **14. How is memory managed in python ?**
# >
# > **Ans.In python memory management can be done using a private heap
# > space that stores our program**
# >
# > **and data.**
# >
# > **15. How to install python on Windows and set path variables.**
# >
# > **Ans. 1. Select pyhton version.**
# >
# > **2. Download python Executable installer**
# >
# > **3. Run Executable Installer .**
# >
# > **4. Add python to path .**
# >
# > **5. Verify python which installed on windows.**
# >
# > **6.Install virtual environment.**
# >
# > **<u>Step for setup path variable</u> :**
# >
# > **1. Locate python Installation.**
# >
# > **2. Verify python Instalaltion**
# > **3. Add python to path as a Environment variable.**
# > **4. Add python path to user Environmental variable.**
# >
# > **5. Check if the Environment is set or not set.**
# >
# > **16. Is indentation required in python ?**
# >
# > **Ans. Yes, python reequired indentaion which help to indicate a block
# > of code.**
