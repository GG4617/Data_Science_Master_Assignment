# %% [markdown]
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><strong>PYTHON</strong></th>
# <th><blockquote>
# <p><strong>: <u>Assignment Questions</u></strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > <u>Assignment</u> **2<u>:</u>**
# >
# > 1\. Write a program to accept percentage from the user and display the
# > grade according to the
# >
# > following ?
# >
# > Marks \>90 =A , Marks \>80 and \<=90 =B , Marks \>=60 and \<=80 = C ,
# > Marks below 60 = D
# >
# > **<u>Code :</u>**
# >
# > percentage = float(input("Enter the percentage: "))
# >
# > if percentage \> 90:
# >
# > grade = "A"
# >
# > elif percentage \> 80 and percentage \<= 90:
# >
# > grade = "B"
# >
# > elif percentage \>= 60 and percentage \<= 80:
# >
# > grade = "C"
# >
# > else:
# >
# > grade = "D"
# >
# > print(f"The grade for {percentage}% is {grade}")
# >
# > 2\. Write a program to accept the cost price of a bike and display the
# > road tax to be paid
# >
# > according to the ?
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Tax</p>
# </blockquote></th>
# <th><blockquote>
# <p>Cost Price (in Rs)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>15%</p>
# </blockquote></td>
# <td><blockquote>
# <p>&gt;100000</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>10%</p>
# </blockquote></td>
# <td><blockquote>
# <p>&gt;50000 and &lt;=100000</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>5%</p>
# </blockquote></td>
# <td><blockquote>
# <p>&lt;=50000</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **<u>Code :</u>**
# >
# > cost_price = float(input("Enter the cost price of the bike (in Rs):
# > "))
# >
# > if cost_price \> 100000:
# >
# > tax = cost_price \* 0.15
# >
# > elif cost_price \> 50000 and cost_price \<= 100000:
# >
# > tax = cost_price \* 0.10
# >
# > else:
# >
# > tax = cost_price \* 0.05
# >
# > print(f"The road tax for a bike with a cost price of Rs {cost_price}
# > is Rs {tax}")
# >
# > 3\. Accept any city from the user **and** display monuments of
# > **that** city.
# >
# > City: Delhi = Red Fort
# >
# > Taj Mahal =Agra
# >
# > Jaipur =Jal Mahal
# >
# > **<u>Code :</u>**
# >
# > city = input("Enter the name of the city: ")
# >
# > if city.lower() == "delhi":
# >
# > monuments = ("Red Fort")
# >
# > elif city.lower() == "agra":
# >
# > monuments = ("Taj Mahal")
# >
# > elif city.lower() == "jaipur":
# >
# > monuments = ("Jal Mahal")
# >
# > else:
# >
# > monuments = ("Monuments not found for this city")
# >
# > print(f"The monuments in {city} are:")
# >
# > for monument in monuments:
# >
# > print(monument)
# >
# > print(f"The monuments in {city} are:")
# >
# > for monument in monuments:
# >
# > print(monument)
# >
# > 4\. Check how many times a given number can be divided **by** 3 before
# > it is less than or equal to
# >
# > 10\.
# >
# > Ans : number = int(input("Enter a number: "))
# >
# > count = 0
# >
# > while number \> 10:
# >
# > number /= 3
# >
# > count += 1
# >
# > print(f"The number can be divided by 3 {count} times before it is less
# > than or equal to 10.")
# >
# > 5\. Why and When to Use while Loop **in Python give** a detailed
# > description with example ?
# >
# > **<u>Ans</u>** :A while loop is used to execute a block of code
# > repeatedly until the condition of while loop
# >
# > must be satisfied.The loop keeps running until the condition (user
# > input must be valid )becomes
# >
# > falses.
# >
# > 6\. Use nested while loop to **print 3** different pattern.
# >
# > Ans : **<u>Square pattern</u>** :
# >
# > rows = 5
# >
# > i = 1
# >
# > while i \<= rows:
# >
# > j = 1
# >
# > while j \<= rows:
# >
# > print("\*", end=" ")
# >
# > j += 1
# >
# > print()
# >
# > i += 1
# >
# > **<u>Rectangle pattern</u>** :
# >
# > rows = 5
# >
# > cols = 10
# >
# > i = 1
# >
# > while i \<= rows:
# >
# > j = 1
# >
# > while j \<= cols:
# >
# > print("\*", end=" ")
# >
# > j += 1
# >
# > print()
# >
# > i += 1
# >
# > **<u>Triangle</u>** :
# >
# > rows = 5
# >
# > i = 1
# >
# > while i \<= rows:
# >
# > j = 1
# >
# > while j \<= i:
# >
# > print("\*", end=" ")
# >
# > j += 1
# >
# > print()
# >
# > i += 1
# >
# > **7.** Reverse a while loop to **display** numbers from 10 to 1.
# >
# > Code :
# >
# > i = 10
# >
# > while i \>= 1:
# >
# > print(i)
# >
# > i -= 1
# >
# > 8\. Reverse a while loop to display numbers from 10 to **1**
# >
# > **Code :**
# >
# > i = 1
# >
# > while i \<= 10:
# >
# > print(11 - i)
# >
# > i += 1
